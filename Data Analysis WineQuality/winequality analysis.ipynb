# %%
import pandas as pd

# %%
df = pd.read_csv('winequality-red.csv',delimiter=';')
print(df.head())
# Out:
#                                                          fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.4  0.70 0.00 1.9 0.076 11.0 34.0 0.9978 3.51 0.56 9.4                                                  5
# 7.8  0.88 0.00 2.6 0.098 25.0 67.0 0.9968 3.20 0.68 9.8                                                  5
#      0.76 0.04 2.3 0.092 15.0 54.0 0.9970 3.26 0.65 9.8                                                  5
# 11.2 0.28 0.56 1.9 0.075 17.0 60.0 0.9980 3.16 0.58 9.8                                                  6
# 7.4  0.70 0.00 1.9 0.076 11.0 34.0 0.9978 3.51 0.56 9.4                                                  5

# %%
file_path = pd.read_csv('winequality-white.csv', delimiter=';')
print(file_path.head())
# Out:
#                                                            fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.0 0.27 0.36 20.7 0.045 45.0 170.0 1.0010 3.00 0.45 8.8                                                   6
# 6.3 0.30 0.34 1.6  0.049 14.0 132.0 0.9940 3.30 0.49 9.5                                                   6
# 8.1 0.28 0.40 6.9  0.050 30.0 97.0  0.9951 3.26 0.44 10.1                                                  6
# 7.2 0.23 0.32 8.5  0.058 47.0 186.0 0.9956 3.19 0.40 9.9                                                   6
#                                                      9.9                                                   6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  4898 non-null   object
# dtypes: object(1)
# memory usage: 38.4+ KB

# %%
import pandas as pd

# Specify the correct delimiter
df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1599 entries, (7.4, 0.7, 0.0, 1.9, 0.076, 11.0, 34.0, 0.9978, 3.51, 0.56, 9.4) to (6.0, 0.31, 0.47, 3.6, 0.067, 18.0, 42.0, 0.99549, 3.39, 0.66, 11.0)
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  1599 non-null   int64
# dtypes: int64(1)
# memory usage: 90.2 KB

# %%
df.describe()
# Out:
#        fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# count                                        1599.000000
# mean                                            5.636023
# std                                             0.807569
# min                                             3.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             8.000000

# %%
file_path.describe()
# Out:
#        fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# count                                                4898
# unique                                               3961
# top     7.3;0.19;0.27;13.9;0.057;45;155;0.99807;2.94;0...
# freq                                                    8

# %%
df.isnull()
# Out:
#                                                             fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.4  0.700 0.00 1.9 0.076 11.0 34.0 0.99780 3.51 0.56 9.4                                               False
# 7.8  0.880 0.00 2.6 0.098 25.0 67.0 0.99680 3.20 0.68 9.8                                               False
#      0.760 0.04 2.3 0.092 15.0 54.0 0.99700 3.26 0.65 9.8                                               False
# 11.2 0.280 0.56 1.9 0.075 17.0 60.0 0.99800 3.16 0.58 9.8                                               False
# 7.4  0.700 0.00 1.9 0.076 11.0 34.0 0.99780 3.51 0.56 9.4                                               False
# ...                                                                                                       ...
# ...

# %%
file_path.isnull()
# Out:
#                                                             fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.0 0.27 0.36 20.7 0.045 45.0 170.0 1.00100 3.00 0.45 8.8                                               False
# 6.3 0.30 0.34 1.6  0.049 14.0 132.0 0.99400 3.30 0.49 9.5                                               False
# 8.1 0.28 0.40 6.9  0.050 30.0 97.0  0.99510 3.26 0.44 10.1                                              False
# 7.2 0.23 0.32 8.5  0.058 47.0 186.0 0.99560 3.19 0.40 9.9                                               False
#                                                       9.9                                               False
# ...                                                                                                       ...
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    0
# dtype: int64

# %%
import pandas as pd

# Correctly read the CSV file with a semicolon as the delimiter
df = pd.read_csv("winequality-red.csv", delimiter=';')

# Display the first few rows to verify the data
print(df.head())

# Check for missing values in the DataFrame
missing_values = df.isnull().sum()
print(missing_values)
# Out:
#                                                          fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.4  0.70 0.00 1.9 0.076 11.0 34.0 0.9978 3.51 0.56 9.4                                                  5
# 7.8  0.88 0.00 2.6 0.098 25.0 67.0 0.9968 3.20 0.68 9.8                                                  5
#      0.76 0.04 2.3 0.092 15.0 54.0 0.9970 3.26 0.65 9.8                                                  5
# 11.2 0.28 0.56 1.9 0.075 17.0 60.0 0.9980 3.16 0.58 9.8                                                  6
# 7.4  0.70 0.00 1.9 0.076 11.0 34.0 0.9978 3.51 0.56 9.4                                                  5
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    0
# dtype: int64

# %%
import pandas as pd

# Correctly read the CSV file with a semicolon as the delimiter
df = pd.read_csv("winequality-white.csv", delimiter=';')

# Display the first few rows to verify the data
print(df.head())

# Check for missing values in the DataFrame
missing_values = df.isnull().sum()
print(missing_values)
# Out:
#                                                            fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.0 0.27 0.36 20.7 0.045 45.0 170.0 1.0010 3.00 0.45 8.8                                                   6
# 6.3 0.30 0.34 1.6  0.049 14.0 132.0 0.9940 3.30 0.49 9.5                                                   6
# 8.1 0.28 0.40 6.9  0.050 30.0 97.0  0.9951 3.26 0.44 10.1                                                  6
# 7.2 0.23 0.32 8.5  0.058 47.0 186.0 0.9956 3.19 0.40 9.9                                                   6
#                                                      9.9                                                   6
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
df.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
import seaborn as sb  # Import seaborn with alias 'sb'
import matplotlib.pyplot as plt

# Create a figure with a specified size
plt.figure(figsize=(12, 12))

# Plot a heatmap of correlations greater than 0.7
sb.heatmap(df.corr() > 0.7, annot=True, cbar=False)

# Show the plot
plt.show()

# %%
print(df.columns)
# Out:
# Index(['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'], dtype='object')

# %%
import matplotlib.pyplot as plt
file_path.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
import seaborn as sb  # Import seaborn with alias 'sb'
import matplotlib.pyplot as plt

# Create a figure with a specified size
plt.figure(figsize=(12, 12))

# Plot a heatmap of correlations greater than 0.7
sb.heatmap(file_path.corr() > 0.7, annot=True, cbar=False)

# Show the plot
plt.show()
